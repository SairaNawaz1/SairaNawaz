# %%
# !pwd
# Out:
# /Users/rmrazack/Documents/SairaNawaz/lessons/lesson-05/code

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 

df = pd.read_csv("./datasets/dataset.csv")

# %%
# create a histogram for the dataFrame
measurements = df.measurements
measurements.plot( kind = "hist" )

# %%
# find the length of measurements
n = len( measurements )

# %%
# get the mean and standard_deviation of the dataset
mean = measurements.mean()
print (mean)

stdev = measurements.std()
print (stdev)
# Out:
# 14.022428279133333
# 6.7304272117257895

# %%
# sort measurements from least to greatest
measurementsSorted = np.sort( measurements )

# %%
print( measurementsSorted )
# Out:
# [  0.65420069   2.51073122   3.57326044   6.32880343   9.6196068
#    9.68612379   9.93590727   9.95752217  10.43264987  11.52707377
#   11.66162395  11.95896084  12.13868406  12.61624737  12.82338917
#   14.64197822  14.975124    15.52200558  15.81075811  15.82163004
#   16.85730122  16.95646689  17.40759363  17.53112835  17.56077884
#   20.1448896   20.22467755  20.95836562  29.37931847  31.45604741]

# %%
# generate n numbers from a normal distribution with same mean and stdev; using the random number generator
# sort these numbers from least to greatest

numsNormal = np.random.normal(loc=mean, scale=stdev, size=n)
numsNormal = np.sort( numsNormal )

# %%
# generate n numbers from a exponential distribution, note you need the rate parameter for exponential

numsExponential = np.random.exponential( scale = mean, size=n )
numsExponential = np.sort( numsExponential )

# %%
# generate n numbers from a uniform distribution, note you need a, and b parameters for uniform ( min and max )

minNum = measurements.min()
maxNum = measurements.max()

numsUniform = np.random.uniform( low = minNum, high = maxNum, size = n )
numsUniform = np.sort( numsUniform )

# %%
# print a scatter plot of actual quantiles (your sorted dataset) vs hypothetical quantiles (generated numbers)
# from each distribution.

objects = {
            "measurements" : measurementsSorted, 
            "numsNormal"   : numsNormal, 
            "numsExponential" : numsExponential,
            "numsUniform" : numsUniform
          }

df = pd.DataFrame( objects )

# %%
import seaborn as sns
from scipy import stats

def r2(x, y):
    return stats.pearsonr(x, y)[0] ** 2
# exponential is a huge left (negative) skew
sns.jointplot(df.numsNormal, df.measurements, kind="reg", stat_func=r2)
sns.jointplot(df.numsExponential, df.measurements, kind="reg", stat_func=r2)
sns.jointplot(df.numsUniform, df.measurements, kind="reg", stat_func=r2)
# Out:
# /Users/rmrazack/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import statsmodels.formula.api as smf
# use for loop not to save, but you can use list comprehensive and functional (mapping); still need to do a loop
formulas = ['measurements ~ numsNormal', 
            'measurements ~ numsExponential', 
            'measurements ~ numsUniform']

def fitModel(formula):
    return smf.ols(formula, data=df).fit()

for formula in formulas:
    results = fitModel(formula)
    print (results.summary())

#models = [ fitModel(formula).summary() for formula is formulas ]

#models2 = map( lambda formula: fitModel(formula).summary, formulas)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           measurements   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     422.7
# Date:                Wed, 07 Dec 2016   Prob (F-statistic):           1.96e-18
# Time:                        20:36:28   Log-Likelihood:                -57.579
# No. Observations:                  30   AIC:                             119.2
# Df Residuals:                      28   BIC:                             122.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      4.7267      0.549      8.607      0.000         3.602     5.852
# numsNormal     0.8196      0.040     20.560      0.000         0.738     0.901
# ==============================================================================
# Omnibus:                        4.217   Durbin-Watson:                   1.053
# Prob(Omnibus):                  0.121   Jarque-Bera (JB):                2.747
# Skew:                           0.465   Prob(JB):                        0.253
# Kurtosis:                       4.155   Cond. No.                         24.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           measurements   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     136.8
# Date:                Wed, 07 Dec 2016   Prob (F-statistic):           2.72e-12
# Time:                        20:36:28   Log-Likelihood:                -72.670
# No. Observations:                  30   AIC:                             149.3
# Df Residuals:                      28   BIC:                             152.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           8.2508      0.714     11.563      0.000         6.789     9.712
# numsExponential     0.3865      0.033     11.697      0.000         0.319     0.454
# ==============================================================================
# Omnibus:                       14.538   Durbin-Watson:                   0.570
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.668
# Skew:                          -1.531   Prob(JB):                     0.000653
# Kurtosis:                       4.537   Cond. No.                         29.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           measurements   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     155.9
# Date:                Wed, 07 Dec 2016   Prob (F-statistic):           5.79e-13
# Time:                        20:36:28   Log-Likelihood:                -71.022
# No. Observations:                  30   AIC:                             146.0
# Df Residuals:                      28   BIC:                             148.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       4.2795      0.920      4.651      0.000         2.395     6.164
# numsUniform     0.6537      0.052     12.488      0.000         0.546     0.761
# ==============================================================================
# Omnibus:                        5.647   Durbin-Watson:                   0.535
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                4.132
# Skew:                           0.873   Prob(JB):                        0.127
# Kurtosis:                       3.506   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# KS testing assumes that you know the population parameters; Anderson Darling testing; chi square testing; q-q testing; can use Maximum Likelihood Estimators use the MLE - used for paramater estimation
